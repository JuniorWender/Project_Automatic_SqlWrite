# %%
import pandas as pd

tabela = pd.read_excel("IdiomasAMT.xlsx") # Import a xlsx file

display(tabela) # show this xlsx file
# Out:
#      CODIGOITEMMENU CODIGOIDIOMA                NOMEITEMMENU ADICIONA/ALTERA  \
# 0                 1           en                     Storage         alterar
# 1                 1           es              Almacenamiento         alterar
# 2                 2           es                   Operación         alterar
# 3                 3           es             Registro Básico         alterar
# 4                 4           es       Tipos de divergencias         alterar
# ..              ...          ...                         ...             ...
# 342            1006           en  Consult Electronic Invoice         alterar
# 343            1007           es                   Compañías         alterar
# 344            1008           es                    Usuarios         alterar
# 345            1011           es                     Ajustes         alterar
# 346            1013           es   Calendario de Operaciones         alterar
#
#     FAZER Unnamed: 5
# 0     NaN        NaN
# 1     NaN        NaN
# 2     NaN        NaN
# 3     NaN        NaN
# 4     NaN        NaN
# ..    ...        ...
# 342   NaN        NaN
# 343   NaN        NaN
# 344   NaN        NaN
# 345   NaN        NaN
# 346   NaN        NaN
#
# [347 rows x 6 columns]

# %%
for linha, CodigoMenu in enumerate(tabela["CODIGOITEMMENU"]): 
    Idioma = tabela.loc[linha, "CODIGOIDIOMA"]
    Nome = tabela.loc[linha, "NOMEITEMMENU"]
    Adicionar_Alterar = tabela.loc[linha, "ADICIONA/ALTERA"]
    Testagem = tabela.loc[linha, "FAZER"]
    Codigo_Completo = []
 
    if (Adicionar_Alterar == "alterar"):
        Codigo_Completo = "UPDATE IDIOMASMENU SET NOMEITEMMENU = " + "'" + Nome + "'" + " WHERE CODIGOITEMMENU = " + str(CodigoMenu) + " AND CODIGOIDIOMA = " + "'" + Idioma + "' ;"
        print(Codigo_Completo)
        print("")
    if (Adicionar_Alterar == "adicionar"):
        Codigo_Completo = "INSERT INTO IDIOMASMENU (CODIGOITEMMENU, CODIGOIDIOMA, NOMEITEMMENU) VALUES( " + str(CodigoMenu) + ", '" + Idioma + "' ," + "'" + Nome +"' ) ;"
        print(Codigo_Completo)
        print("")
# Out:
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Storage' WHERE CODIGOITEMMENU = 1 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Almacenamiento' WHERE CODIGOITEMMENU = 1 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Operación' WHERE CODIGOITEMMENU = 2 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registro Básico' WHERE CODIGOITEMMENU = 3 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de divergencias' WHERE CODIGOITEMMENU = 4 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipo de Acciones Para Ajustar Divergencias' WHERE CODIGOITEMMENU = 5 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de modos de transporte' WHERE CODIGOITEMMENU = 6 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de señales del IRS' WHERE CODIGOITEMMENU = 8 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de procesos' WHERE CODIGOITEMMENU = 9 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de especies' WHERE CODIGOITEMMENU = 12 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Productos' WHERE CODIGOITEMMENU = 13 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Productos' WHERE CODIGOITEMMENU = 14 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Acciones Para Los Planes de Almacenamiento' WHERE CODIGOITEMMENU = 16 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de eventos com productos almacenados' WHERE CODIGOITEMMENU = 17 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cualificaciones de la ubicación de almacenamiento' WHERE CODIGOITEMMENU = 19 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ubicaciones de Almacenamiento' WHERE CODIGOITEMMENU = 20 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Documentos Fiscales' WHERE CODIGOITEMMENU = 22 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Importación de Documentos Fiscales' WHERE CODIGOITEMMENU = 23 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Requisitos Estándar Para Procesos' WHERE CODIGOITEMMENU = 24 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Procesos' WHERE CODIGOITEMMENU = 25 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Process' WHERE CODIGOITEMMENU = 25 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Planes de Almacenamiento' WHERE CODIGOITEMMENU = 26 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Recepción de productos' WHERE CODIGOITEMMENU = 27 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registros de movimiento' WHERE CODIGOITEMMENU = 28 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Autorizaciones de lanzamiento de productos' WHERE CODIGOITEMMENU = 29 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Salida Del Producto' WHERE CODIGOITEMMENU = 30 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Envío de Productos' WHERE CODIGOITEMMENU = 31 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Horario de embarque' WHERE CODIGOITEMMENU = 32 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Consultar posición de productos para envío' WHERE CODIGOITEMMENU = 33 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Visualización gráfica de ubicaciones de almacenamiento' WHERE CODIGOITEMMENU = 35 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registros Básicos' WHERE CODIGOITEMMENU = 37 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Compañías' WHERE CODIGOITEMMENU = 38 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Países' WHERE CODIGOITEMMENU = 43 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Puertos' WHERE CODIGOITEMMENU = 45 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Puertos' WHERE CODIGOITEMMENU = 46 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Terminales' WHERE CODIGOITEMMENU = 47 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cargadero' WHERE CODIGOITEMMENU = 48 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Dársena' WHERE CODIGOITEMMENU = 49 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Equipamientos' WHERE CODIGOITEMMENU = 50 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Equipamientos' WHERE CODIGOITEMMENU = 51 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Equipos' WHERE CODIGOITEMMENU = 52 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Tiempo de Inactividad del Equipo' WHERE CODIGOITEMMENU = 53 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Equipment stop type' WHERE CODIGOITEMMENU = 53 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registro del Historial de Mantenimiento' WHERE CODIGOITEMMENU = 54 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Maintenance History Registration' WHERE CODIGOITEMMENU = 54 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Responsable de Mantenimiento' WHERE CODIGOITEMMENU = 55 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Mano de Obra' WHERE CODIGOITEMMENU = 56 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Buques' WHERE CODIGOITEMMENU = 57 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Buques' WHERE CODIGOITEMMENU = 58 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Shipowners' WHERE CODIGOITEMMENU = 59 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Bandera' WHERE CODIGOITEMMENU = 60 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Datos de importacion' WHERE CODIGOITEMMENU = 61 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Barcos' WHERE CODIGOITEMMENU = 62 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Agencia Marítima' WHERE CODIGOITEMMENU = 63 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Agencia Marítima' WHERE CODIGOITEMMENU = 64 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Recurso de Movilización' WHERE CODIGOITEMMENU = 72 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipo de Movilización de Recursos' WHERE CODIGOITEMMENU = 73 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Actividades de Movilización de Recursos' WHERE CODIGOITEMMENU = 74 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Apagones' WHERE CODIGOITEMMENU = 75 AND CODIGOIDIOMA = 'es' ;
#
# INSERT INTO IDIOMASMENU (CODIGOITEMMENU, CODIGOIDIOMA, NOMEITEMMENU) VALUES( 76, 'es' ,'Categoría de Trabajador Separada' ) ;
#
# INSERT INTO IDIOMASMENU (CODIGOITEMMENU, CODIGOIDIOMA, NOMEITEMMENU) VALUES( 76, 'pt' ,'Categoria de Trabalhador Separada' ) ;
#
# INSERT INTO IDIOMASMENU (CODIGOITEMMENU, CODIGOIDIOMA, NOMEITEMMENU) VALUES( 77, 'es' ,'Funciones de Trabajador Independiente' ) ;
#
# INSERT INTO IDIOMASMENU (CODIGOITEMMENU, CODIGOIDIOMA, NOMEITEMMENU) VALUES( 77, 'pt' ,'Função de Trabalhador Separada' ) ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Funciones Generales de Los Trabajadores' WHERE CODIGOITEMMENU = 78 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Orden de Servicio' WHERE CODIGOITEMMENU = 80 AND CODIGOIDIOMA = 'es' ;
#
# INSERT INTO IDIOMASMENU (CODIGOITEMMENU, CODIGOIDIOMA, NOMEITEMMENU) VALUES( 81, 'es' ,'Entrada de Trabajo Independiente' ) ;
#
# INSERT INTO IDIOMASMENU (CODIGOITEMMENU, CODIGOIDIOMA, NOMEITEMMENU) VALUES( 81, 'pt' ,'Entrada de trabalho separada' ) ;
#
# INSERT INTO IDIOMASMENU (CODIGOITEMMENU, CODIGOIDIOMA, NOMEITEMMENU) VALUES( 82, 'en' ,'Appropriation of Resources' ) ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Embarque / Aterrizaje' WHERE CODIGOITEMMENU = 84 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Financiero' WHERE CODIGOITEMMENU = 107 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'La Seguridad' WHERE CODIGOITEMMENU = 108 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Administracion del Sistema' WHERE CODIGOITEMMENU = 110 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Usuarios' WHERE CODIGOITEMMENU = 111 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Flujo de Aprobación' WHERE CODIGOITEMMENU = 112 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Perfiles de Acceso al Sistema' WHERE CODIGOITEMMENU = 113 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Presupuesto de Oportunidad' WHERE CODIGOITEMMENU = 128 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Nominaciones' WHERE CODIGOITEMMENU = 129 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Asistencia' WHERE CODIGOITEMMENU = 130 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Planificación anual de operaciones' WHERE CODIGOITEMMENU = 131 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Gastos Generales Del Buque' WHERE CODIGOITEMMENU = 132 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Suministros a Los Barcos' WHERE CODIGOITEMMENU = 133 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informe Para La Contabilización de Notas de Débito' WHERE CODIGOITEMMENU = 134 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Aprobaciones' WHERE CODIGOITEMMENU = 135 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cola de Aprobación' WHERE CODIGOITEMMENU = 136 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Gastos de Oportunidad' WHERE CODIGOITEMMENU = 137 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipo de Gastos de Envío' WHERE CODIGOITEMMENU = 138 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Listas de verificación' WHERE CODIGOITEMMENU = 140 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Horario' WHERE CODIGOITEMMENU = 141 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Suministro a Los Buques' WHERE CODIGOITEMMENU = 142 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Fletadores' WHERE CODIGOITEMMENU = 144 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Supervisores de Estiba' WHERE CODIGOITEMMENU = 145 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Empresas de Empeño' WHERE CODIGOITEMMENU = 147 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tabla de Precios' WHERE CODIGOITEMMENU = 148 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Parámetro de presupuesto de oportunidad' WHERE CODIGOITEMMENU = 149 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tablas de Costos de Almacenamiento' WHERE CODIGOITEMMENU = 150 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tiempos estándar de llegada de productos' WHERE CODIGOITEMMENU = 157 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Antiguo horario de funcionamiento' WHERE CODIGOITEMMENU = 158 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cargadores' WHERE CODIGOITEMMENU = 159 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Shippers' WHERE CODIGOITEMMENU = 159 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Patio de Secuenciación' WHERE CODIGOITEMMENU = 160 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registro Básico' WHERE CODIGOITEMMENU = 161 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Terminal de Patio de Secuenciación' WHERE CODIGOITEMMENU = 162 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'tiempo de espera de retraso' WHERE CODIGOITEMMENU = 163 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registro de Composiciones' WHERE CODIGOITEMMENU = 164 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Líneas Ferroviarias' WHERE CODIGOITEMMENU = 165 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Solicitantes de Maniobras' WHERE CODIGOITEMMENU = 166 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Disponibilidad de trenes em VALE' WHERE CODIGOITEMMENU = 167 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Recepción em el Patio de Secuenciación' WHERE CODIGOITEMMENU = 168 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Información de recepción em el patio de secuenciación' WHERE CODIGOITEMMENU = 169 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Solicitud de Maniobra' WHERE CODIGOITEMMENU = 170 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Recibo em el puerto' WHERE CODIGOITEMMENU = 171 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Regresa al Patio de Secuenciación' WHERE CODIGOITEMMENU = 172 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Volver a VALE' WHERE CODIGOITEMMENU = 173 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Retirado por VALE' WHERE CODIGOITEMMENU = 174 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Diferencias Encontradas' WHERE CODIGOITEMMENU = 176 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Turno de Inicio' WHERE CODIGOITEMMENU = 181 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Shart Shift' WHERE CODIGOITEMMENU = 181 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Paros' WHERE CODIGOITEMMENU = 182 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Comentarios de turno' WHERE CODIGOITEMMENU = 183 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Shift Comments' WHERE CODIGOITEMMENU = 183 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Envíos' WHERE CODIGOITEMMENU = 185 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cerrar Turno' WHERE CODIGOITEMMENU = 186 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Vacaciones' WHERE CODIGOITEMMENU = 187 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Holidays' WHERE CODIGOITEMMENU = 187 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Empleados' WHERE CODIGOITEMMENU = 188 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Employees' WHERE CODIGOITEMMENU = 188 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Grupo de Empleados' WHERE CODIGOITEMMENU = 189 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Group of Employees' WHERE CODIGOITEMMENU = 189 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Sustituciones' WHERE CODIGOITEMMENU = 190 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Generación de Escala' WHERE CODIGOITEMMENU = 191 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Scale Generation' WHERE CODIGOITEMMENU = 191 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Estructura de Amarre' WHERE CODIGOITEMMENU = 194 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Falta de Envíos' WHERE CODIGOITEMMENU = 196 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Razones Para Esperar El Atraque' WHERE CODIGOITEMMENU = 201 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Destinatario de RICE' WHERE CODIGOITEMMENU = 203 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Grupo de Cargadores' WHERE CODIGOITEMMENU = 204 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Group of Shippers' WHERE CODIGOITEMMENU = 204 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Planificación Mensual' WHERE CODIGOITEMMENU = 208 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Composición Pendiente de Documentación' WHERE CODIGOITEMMENU = 217 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informes' WHERE CODIGOITEMMENU = 221 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Diferencias y Acciones Necesarias' WHERE CODIGOITEMMENU = 222 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Entrada y Salida de Productos' WHERE CODIGOITEMMENU = 223 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Procesos Pendientes' WHERE CODIGOITEMMENU = 224 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Productos Almacenados' WHERE CODIGOITEMMENU = 225 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tiempo de Almacenamiento' WHERE CODIGOITEMMENU = 226 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Costos de Almacenamiento' WHERE CODIGOITEMMENU = 227 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Control de Almacenamiento de Productos' WHERE CODIGOITEMMENU = 228 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informes' WHERE CODIGOITEMMENU = 229 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Historial de Embarque' WHERE CODIGOITEMMENU = 230 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Uso de Dársena' WHERE CODIGOITEMMENU = 231 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Carga Esperada X Realizada' WHERE CODIGOITEMMENU = 232 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Uso de Equipo' WHERE CODIGOITEMMENU = 233 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Envíos Consolidados' WHERE CODIGOITEMMENU = 234 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Uso general de Las Dársena' WHERE CODIGOITEMMENU = 235 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Envío por Producto' WHERE CODIGOITEMMENU = 236 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Shipment by product' WHERE CODIGOITEMMENU = 236 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Paros' WHERE CODIGOITEMMENU = 237 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Seguimiento de Envío Mensual' WHERE CODIGOITEMMENU = 238 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informes' WHERE CODIGOITEMMENU = 239 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Disponibilidad de Líneas Ferroviarias' WHERE CODIGOITEMMENU = 240 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Controlar el Tren' WHERE CODIGOITEMMENU = 241 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Controle dos trens' WHERE CODIGOITEMMENU = 241 AND CODIGOIDIOMA = 'pt' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cargos por Demora' WHERE CODIGOITEMMENU = 242 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Movimiento de vagones' WHERE CODIGOITEMMENU = 243 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Movimentação de Vagões' WHERE CODIGOITEMMENU = 243 AND CODIGOIDIOMA = 'pt' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Controle de acceso' WHERE CODIGOITEMMENU = 259 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Access Control' WHERE CODIGOITEMMENU = 259 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'zona a visitar' WHERE CODIGOITEMMENU = 260 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'area to be visited' WHERE CODIGOITEMMENU = 260 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'visitor' WHERE CODIGOITEMMENU = 261 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Programar visitas' WHERE CODIGOITEMMENU = 262 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'ocurrencias' WHERE CODIGOITEMMENU = 264 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'occurrences' WHERE CODIGOITEMMENU = 264 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Ocurrencia' WHERE CODIGOITEMMENU = 267 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registros de Ocurrencia' WHERE CODIGOITEMMENU = 268 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informes' WHERE CODIGOITEMMENU = 274 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Reports' WHERE CODIGOITEMMENU = 274 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'ocurrencias' WHERE CODIGOITEMMENU = 275 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Costo' WHERE CODIGOITEMMENU = 295 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cost' WHERE CODIGOITEMMENU = 295 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registro Básico' WHERE CODIGOITEMMENU = 296 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Basic  Registration' WHERE CODIGOITEMMENU = 296 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Centro de Costos' WHERE CODIGOITEMMENU = 297 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Condominios' WHERE CODIGOITEMMENU = 298 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cuentas Financiera' WHERE CODIGOITEMMENU = 299 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Clasificaciones' WHERE CODIGOITEMMENU = 300 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Types of Classifications' WHERE CODIGOITEMMENU = 300 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Prorrateo' WHERE CODIGOITEMMENU = 301 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Apportionment' WHERE CODIGOITEMMENU = 301 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informes' WHERE CODIGOITEMMENU = 302 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Costo Operativo Detallado' WHERE CODIGOITEMMENU = 303 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Detailed Operating Cost' WHERE CODIGOITEMMENU = 303 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Consultar Hoja de Trabajo de Costos Operativos' WHERE CODIGOITEMMENU = 304 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ingresos X Gasto' WHERE CODIGOITEMMENU = 305 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Presupuestado X Logrado' WHERE CODIGOITEMMENU = 306 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Abrir y Cerrar Mes Fiscal' WHERE CODIGOITEMMENU = 307 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Distribución de Costos' WHERE CODIGOITEMMENU = 308 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cost Distribution' WHERE CODIGOITEMMENU = 308 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Hombre / Hora Vendido' WHERE CODIGOITEMMENU = 309 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Man / Hour Sold' WHERE CODIGOITEMMENU = 309 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Horas / Máquina em el mês por empresa' WHERE CODIGOITEMMENU = 310 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Avances' WHERE CODIGOITEMMENU = 311 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ingresos' WHERE CODIGOITEMMENU = 312 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Distribución de Personal' WHERE CODIGOITEMMENU = 313 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Configurar Prorrateo' WHERE CODIGOITEMMENU = 314 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Transacciones de Importación Realizadas' WHERE CODIGOITEMMENU = 315 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Puntos de Vista Gerenciales' WHERE CODIGOITEMMENU = 316 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registro de Lanzamientos' WHERE CODIGOITEMMENU = 317 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Costo Del Tonelaje Del Envío' WHERE CODIGOITEMMENU = 318 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Gran Total de Costos' WHERE CODIGOITEMMENU = 319 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Clasificar Cuentas Contables' WHERE CODIGOITEMMENU = 320 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Costos Fijos X Coste Variable' WHERE CODIGOITEMMENU = 321 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Panel de Gestión' WHERE CODIGOITEMMENU = 322 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Viaje em Barco' WHERE CODIGOITEMMENU = 323 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ver Cronograma de Operaciones' WHERE CODIGOITEMMENU = 324 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'View Operation Schedule' WHERE CODIGOITEMMENU = 324 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'técnico mensual' WHERE CODIGOITEMMENU = 325 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Configurar Importación' WHERE CODIGOITEMMENU = 326 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cuenta Contable X Centro de Costo Anual' WHERE CODIGOITEMMENU = 327 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Accounting Account X Annual Cost Center' WHERE CODIGOITEMMENU = 327 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Consultar Flujo de Aprobación' WHERE CODIGOITEMMENU = 328 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Salida Del Vagón' WHERE CODIGOITEMMENU = 329 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ocurrencias Portuarias' WHERE CODIGOITEMMENU = 330 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Port Occurrences' WHERE CODIGOITEMMENU = 330 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registro Básico' WHERE CODIGOITEMMENU = 331 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Basic  Registration' WHERE CODIGOITEMMENU = 331 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ocurrencias Portuarias' WHERE CODIGOITEMMENU = 332 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Port Occurrences' WHERE CODIGOITEMMENU = 332 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informes' WHERE CODIGOITEMMENU = 333 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'reports' WHERE CODIGOITEMMENU = 333 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Caregorías de Fallas' WHERE CODIGOITEMMENU = 334 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Failure Categories' WHERE CODIGOITEMMENU = 334 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Desglose' WHERE CODIGOITEMMENU = 335 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Types of Breakdown' WHERE CODIGOITEMMENU = 335 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Categorías de Accidentes' WHERE CODIGOITEMMENU = 336 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Accident Categories' WHERE CODIGOITEMMENU = 336 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Partes Del Cuerpo' WHERE CODIGOITEMMENU = 337 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Body Parts' WHERE CODIGOITEMMENU = 337 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Categorías de Trabajadores' WHERE CODIGOITEMMENU = 338 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Worker Categories' WHERE CODIGOITEMMENU = 338 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Apropiación de Recursos y Órdenes de Trabajo' WHERE CODIGOITEMMENU = 340 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Desglose' WHERE CODIGOITEMMENU = 341 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Breakdown' WHERE CODIGOITEMMENU = 341 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Accidente' WHERE CODIGOITEMMENU = 342 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Accident' WHERE CODIGOITEMMENU = 342 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Lesiones' WHERE CODIGOITEMMENU = 343 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Injuries' WHERE CODIGOITEMMENU = 343 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Embarque por Diez Días' WHERE CODIGOITEMMENU = 344 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ocurrencias' WHERE CODIGOITEMMENU = 345 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'occurrences' WHERE CODIGOITEMMENU = 345 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Uso de Cunas Realizadas X Previsto' WHERE CODIGOITEMMENU = 346 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cambio de Turno' WHERE CODIGOITEMMENU = 347 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informe de Pedido' WHERE CODIGOITEMMENU = 348 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Horas de Equipo Usadas y no Usadas' WHERE CODIGOITEMMENU = 349 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Cambio de Vagones' WHERE CODIGOITEMMENU = 350 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informes' WHERE CODIGOITEMMENU = 351 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Perfiles de Acceso' WHERE CODIGOITEMMENU = 352 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Access Profiles' WHERE CODIGOITEMMENU = 352 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Horarios de Visita Del Sector' WHERE CODIGOITEMMENU = 353 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Sector Visiting Hours' WHERE CODIGOITEMMENU = 353 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ocurrencias Por Año' WHERE CODIGOITEMMENU = 354 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Occurrences Por Year' WHERE CODIGOITEMMENU = 354 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Clasificación Del Tiempo de Inactividad Del Equipo' WHERE CODIGOITEMMENU = 355 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Types of Equipment Downtime Classification' WHERE CODIGOITEMMENU = 355 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Descripción Del Control de Acceso' WHERE CODIGOITEMMENU = 356 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Access Control Description' WHERE CODIGOITEMMENU = 356 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Estadísticas de Control de Acceso' WHERE CODIGOITEMMENU = 357 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Access Control Statistics' WHERE CODIGOITEMMENU = 357 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipos de Observaciones' WHERE CODIGOITEMMENU = 358 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Types of Observations' WHERE CODIGOITEMMENU = 358 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Importar Mano de Obra Separada' WHERE CODIGOITEMMENU = 359 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Import Separate Labor' WHERE CODIGOITEMMENU = 359 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Planificación Mensual' WHERE CODIGOITEMMENU = 360 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'de Servicio' WHERE CODIGOITEMMENU = 361 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'On Duty' WHERE CODIGOITEMMENU = 361 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Correos Electrónicos de OGMO' WHERE CODIGOITEMMENU = 362 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Emails From OGMO' WHERE CODIGOITEMMENU = 362 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Controles de Retardo' WHERE CODIGOITEMMENU = 365 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Delay Controls' WHERE CODIGOITEMMENU = 365 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Órdenes de Servicio por Período' WHERE CODIGOITEMMENU = 366 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Service Orders by Period' WHERE CODIGOITEMMENU = 366 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Desglose de Materiales' WHERE CODIGOITEMMENU = 367 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Material Breakdown' WHERE CODIGOITEMMENU = 367 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Fallas' WHERE CODIGOITEMMENU = 368 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Faults' WHERE CODIGOITEMMENU = 368 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Otros' WHERE CODIGOITEMMENU = 369 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Others' WHERE CODIGOITEMMENU = 369 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Boletín de Medición de Equipos' WHERE CODIGOITEMMENU = 370 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Equipment Measurement Bulletin' WHERE CODIGOITEMMENU = 370 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Averías em Materiales' WHERE CODIGOITEMMENU = 371 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Breakdowns in Materials' WHERE CODIGOITEMMENU = 371 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Permiso Para Notas Posteriores al Desatraque' WHERE CODIGOITEMMENU = 372 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Permission For Post-Unberthing Notes' WHERE CODIGOITEMMENU = 372 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Pendientes' WHERE CODIGOITEMMENU = 373 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Pendencies' WHERE CODIGOITEMMENU = 373 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Conserje' WHERE CODIGOITEMMENU = 375 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Concierge' WHERE CODIGOITEMMENU = 375 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Programar Visita' WHERE CODIGOITEMMENU = 376 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Schedule Visit' WHERE CODIGOITEMMENU = 376 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registro Entrada / Salida' WHERE CODIGOITEMMENU = 377 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Register Entry / Exit' WHERE CODIGOITEMMENU = 377 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Consultar Datos Del Vehículo' WHERE CODIGOITEMMENU = 378 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Consult Vehicle Data' WHERE CODIGOITEMMENU = 378 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Registros Básicos' WHERE CODIGOITEMMENU = 379 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Basic  Registration' WHERE CODIGOITEMMENU = 379 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Razón de la Visita' WHERE CODIGOITEMMENU = 380 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Reason for Visit' WHERE CODIGOITEMMENU = 380 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Importar Registros' WHERE CODIGOITEMMENU = 381 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Import Records' WHERE CODIGOITEMMENU = 381 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Vehículos' WHERE CODIGOITEMMENU = 382 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Vehicles' WHERE CODIGOITEMMENU = 382 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Visitors' WHERE CODIGOITEMMENU = 383 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'zona a visitar' WHERE CODIGOITEMMENU = 384 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Area to be Visited' WHERE CODIGOITEMMENU = 384 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipo de Equipo' WHERE CODIGOITEMMENU = 385 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Kind of Equipment' WHERE CODIGOITEMMENU = 385 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Tipo de Vehiculo' WHERE CODIGOITEMMENU = 386 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Vehicle Type' WHERE CODIGOITEMMENU = 386 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Visitor Type' WHERE CODIGOITEMMENU = 387 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Capacitación' WHERE CODIGOITEMMENU = 388 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Training' WHERE CODIGOITEMMENU = 388 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ocurrencias' WHERE CODIGOITEMMENU = 389 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Occurrences' WHERE CODIGOITEMMENU = 389 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Informes' WHERE CODIGOITEMMENU = 390 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Reports' WHERE CODIGOITEMMENU = 390 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Descripción Del Control de Acceso' WHERE CODIGOITEMMENU = 391 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Access Control Description' WHERE CODIGOITEMMENU = 391 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Factura Electrónica' WHERE CODIGOITEMMENU = 1000 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Electronic Invoice' WHERE CODIGOITEMMENU = 1000 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Panel' WHERE CODIGOITEMMENU = 1001 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Recibo Factura Electrónica' WHERE CODIGOITEMMENU = 1002 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Receive Electronic Invoice' WHERE CODIGOITEMMENU = 1002 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Encuadernación de Factura Electrónica' WHERE CODIGOITEMMENU = 1003 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Lectura Manual' WHERE CODIGOITEMMENU = 1004 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Stock Factura Electrónica' WHERE CODIGOITEMMENU = 1005 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Stock Electronic Invoice' WHERE CODIGOITEMMENU = 1005 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Consultar Factura Electrónica' WHERE CODIGOITEMMENU = 1006 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Consult Electronic Invoice' WHERE CODIGOITEMMENU = 1006 AND CODIGOIDIOMA = 'en' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Compañías' WHERE CODIGOITEMMENU = 1007 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Usuarios' WHERE CODIGOITEMMENU = 1008 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Ajustes' WHERE CODIGOITEMMENU = 1011 AND CODIGOIDIOMA = 'es' ;
#
# UPDATE IDIOMASMENU SET NOMEITEMMENU = 'Calendario de Operaciones' WHERE CODIGOITEMMENU = 1013 AND CODIGOIDIOMA = 'es' ;
